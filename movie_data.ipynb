# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_tv = pd.read_csv("movie_ott_service_211006.csv")
df2 = pd.read_csv("frame.csv")
df2
# Out:
# Empty DataFrame
# Columns: [id, title, genres, overview, poster_path, release_date, runtime, popularity, production_countries]
# Index: []

# %%
df_movie
# Out:
#             id                             title  \
# 0            2                               아리엘
# 1            3                           천국의 그림자
# 2            5                                포룸
# 3            6                            킬러 나이트
# 4            8  Life in Loops (A Megacities RMX)
# ...        ...                               ...
# 691463  881325             Neschastnaya indyanka
# 691464  881326      Milch und Honig aus Rotfront
# 691465  881327                  The Sinful Dwarf
# 691466  881328                DIE WELT DER ADLER
# 691467  881329       SEEADLER - DER VOGEL PHÖNIX
#
#                                                    genres  \
# 0       [{'id': 18, 'name': '드라마'}, {'id': 80, 'name':...
# 1       [{'id': 18, 'name': '드라마'}, {'id': 35, 'name':...
# 2       [{'id': 80, 'name': '범죄'}, {'id': 35, 'name': ...
# 3       [{'id': 28, 'name': '액션'}, {'id': 53, 'name': ...
# 4                           [{'id': 99, 'name': '다큐멘터리'}]
# ...

# %%
# 2019년 인기 영화 제목으로 찾기
list_2019 = ["프랙처드",
"3층의 여자",
"더 런드로맷",
"더 플랫폼",
"오피셜 시크릿",
"싱크로닉",
"문 섀도우",
"시리얼 킬러 연쇄살인범",
"IO",
"3022",
"클로즈",
"예스, 갓, 예스",
"더 킹: 헨리 5세",
"투 더 레이크",
"애프터",
"아이리시맨",
"나는 악마를 사랑했다",
"머더 미스터리",
"일라이",
"내가 누구인지 말해주오",
"6 언더그라운드",
"The Son",
"드렁크 패어런츠",
"프로페서 앤 매드맨",
"파라다이스 힐스",
"언컷 젬스",
"파이브 피트",
"사일런스",
"폴라",
"거대한 해킹",
"레드 씨 다이빙 리조트",
"7번방의 기적",
"피셔맨즈 프렌즈",
"높은 풀 속에서",
"라잉 앤 스틸링",
"트리플 프런티어",
"코드 8",
"림 오브 더 월드",
"시크릿 옵세션",
"팬데믹",
"더 더트",
"포인트 블랭크",
"브레이킹 배드 무비: 엘 카미노",
"또 다른 시간",
"인 이지 걸",
"하이웨이맨",
"나의 마더",
"치킨 트랩",
"유랑지구",
"스텔라를 납치했다"]
             
for i in list_2019:
    df= df_movie[df_movie['title']==i]
    df2=df2.append(df)
    df2 = df2.reset_index(drop=True)
df2.to_csv('movies_top_2019_11.csv', sep=',', na_rep='NaN', index = None)

# %%
dup_df2 = df2[df2.duplicated(["title"])== True]
dup_df2
# Out:
#         id     title                                             genres  \
# 16  483202       일라이                         [{'id': 27, 'name': '공포'}]
# 24  527261      사일런스  [{'id': 27, 'name': '공포'}, {'id': 18, 'name': ...
# 25  726139      사일런스                        [{'id': 53, 'name': '스릴러'}]
# 30  638240   7번방의 기적  [{'id': 18, 'name': '드라마'}, {'id': 35, 'name':...
# 38   61404   포인트 블랭크  [{'id': 28, 'name': '액션'}, {'id': 53, 'name': ...
# 39  531503   포인트 블랭크  [{'id': 28, 'name': '액션'}, {'id': 53, 'name': ...
# 42  500682     하이웨이맨  [{'id': 80, 'name': '범죄'}, {'id': 18, 'name': ...
# 45   30747  The Trap                                                 []
# 46   38472  The Trap  [{'id': 80, 'name': '범죄'}, {'id': 9648, 'name'...
# 47   51445  The Trap  [{'id': 12, 'name': '모험'}, {'id': 18, 'name': ...
# 48   70324  The Trap                         [{'id': 80, 'name': '범죄'}]
# 49  175563  The Trap                        [{'id': 18, 'name': '드라마'}]
# ...

# %%
df2 = pd.read_csv("frame.csv")
df2

# %%
list_2018 = ["레벨 16",
"벌새 프로젝트",
"7월 22일",
"웰컴 홈",
"늑대의 어둠",
"죽어도 살아야 한다",
"러스트 크릭",
"프릭스",
"클로브히치 킬러",
"익스팅션: 종의 구원자",
"우리는 언제나 성에 살았다",
"마일 22",
"아논",            
"침묵의 비명",
"프로스펙트",
"레드 조안",
"오필리아",
"최후의 호흡",
"더 게임 체인저스",
"종말의 끝",
"뮤트",
"더 타이탄",
"찰리 세즈",
"윈체스터",
"데스티네이션 웨딩",
"3층 복도 끝에서",
"오퍼레이션 피날레",
"웨딩 게스트",
"동물세계",
"카우보이의 노래",
"마이 티쳐, 마이 러브",
"아웃사이더",
"어드리프트: 우리가 함께한 바다",
"아이 엠 마더",
"미드나잇 선",
"행복한 남자",
"건지 감자껍질파이 북클럽",
"No Escape Room",
"폭풍의 시간",
"못 말리는 부자들",
"힙합 애프터 파티",
"더 패키지",
"클로버필드 패러독스",
"타우",
"Benji",
"복수의 사도",
"그래도 지구는 평평하다",
"마녀",
"편집가능한 인생",
"아웃로 킹"]

for i in list_2018:
    df= df_movie[df_movie['title']==i]
    print(df)
    df2 = df2.append(df)
    df2 = df2.reset_index(drop=True)

df2.to_csv('movies_top_2018.csv', sep=',', na_rep='NaN', index = None)
# Out:
#             id  title                                             genres  \
# 404238  548066  레벨 16  [{'id': 878, 'name': 'SF'}, {'id': 53, 'name':...
#
#                                                  overview  \
# 404238  10대의 소녀들로 이루어진 기숙사 학교 ‘베스탈리스’ 좋은 집안으로 입양을 가기 위...
#
#                              poster_path release_date  runtime  popularity  \
# 404238  /irD0v3QSH7Zm22dl8OORiTv997A.jpg   2018-02-20    102.0      22.163
#
#                             production_countries
# 404238  [{'iso_3166_1': 'CA', 'name': 'Canada'}]
#             id    title                                             genres  \
# 353119  489243  벌새 프로젝트  [{'id': 53, 'name': '스릴러'}, {'id': 18, 'name':...
#
#                                                  overview  \
# 353119  뉴욕 출신으로 사촌 관계인 빈센트와 안톤은 주식시장에서 백만 분의 일초 차이로 승부...
#
#                              poster_path release_date  runtime  popularity  \
# 353119  /iCD5PHYyLVykHGGhlhkUD7nhoWe.jpg   2019-03-15    111.0       8.453
#
# ...

# %%
df2 = pd.read_csv("frame.csv")
df2
# Out:
# Empty DataFrame
# Columns: [id, title, genres, overview, poster_path, release_date, runtime, popularity, production_countries]
# Index: []

# %%
list_2014 =["블루밍 러브",
"후 엠 아이",
"킬 더 메신저",
"워크 오브 셰임",
"더 게스트",
"쓰리데이즈 투 킬",
"소름",
"사랑에 대한 모든 것",
"에피 그레이",
"블랙 씨",
"소에 관한 음모",
"아메리칸 셰프",
"노벰버 맨",
"7번째 아들",
"디 인터뷰",
"브릭 맨션: 통제불능 범죄구역",
"언프렌디드: 친구삭제",
"스나이퍼: 레거시",
"코펜하겐",
"황혼에서 새벽까지: 시리즈",
"더티 파티",
"사보타지",
"뱀파이어 아카데미",
"엘로이즈",
"제임스 브라운",
"The Fluffy Movie",
"더 배터드 배스터즈 오브 베이스볼",
"Tom Segura: Completely Normal",
"피케이: 별에서 온 얼간이",
"헌티드 하우스 2",
"넛잡: 땅콩 도둑들",
"컷뱅크",
"Honeytrap",
"Khoobsurat",
"A Fairly Odd Summer",
"La dictadura perfecta",
"천재강아지 미스터 피바디",
"마다가스카의 펭귄",
"하이더",
"해피 뉴 이어",
"Swearnet: The Movie",
"비룽가",
"미션 블루",
"조이의 비밀 APP",
"브루클린의 멋진 주말",
"하이웨이",
"도마 위의 정사",
"사라예보",
"She's Dating the Gangster",
"Bill Burr: I'm Sorry You Feel That Way"]

for i in list_2014:
    df= df_movie[df_movie['title']==i]
    print(df)
    df2 = df2.append(df)
    df2 = df2.reset_index(drop=True)

df2.to_csv('movies_top_2014.csv', sep=',', na_rep='NaN', index = None)
# Out:
#             id   title                                             genres  \
# 175257  283227  블루밍 러브  [{'id': 18, 'name': '드라마'}, {'id': 10749, 'nam...
#
#                                                  overview  \
# 175257  루이 14세, 베르사유, 천국을 만들라는 왕의 명령에 정원사들이 모인다.  대대로 ...
#
#                              poster_path release_date  runtime  popularity  \
# 175257  /eIQsfXGbg2HdpMWKc6Gyhx8Eraf.jpg   2015-03-26    117.0       8.764
#
#                                     production_countries
# 175257  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#             id   title                       genres  \
# 176325  284427  후 엠 아이  [{'id': 53, 'name': '스릴러'}]
#
#                                                  overview  \
# 176325  보수 단체의 선거 캠프, 금융권, 제약회사, 신문사, 가구회사 그리고 포느로 사이트...
#
#                              poster_path release_date  runtime  popularity  \
# 176325  /tMFe2NxTTIor99TNt7vHKXLc152.jpg   2014-09-25    105.0      19.315
#
# ...

# %%
df2 = pd.read_csv("frame.csv")
df2
# Out:
# Empty DataFrame
# Columns: [id, title, genres, overview, poster_path, release_date, runtime, popularity, production_countries]
# Index: []

# %%
list_2015 = ["퀸카가 아니어도 좋아",
"핫 걸 원티드",
"바이 더 씨",
"셀프 리스",
"헤이트풀8",
"더 나은 선택",
"데모닉",
"레전드",
"이스케이프",
"써클",
"프레지던트 메이커",
"크림슨 피크",
"6년의 사랑",
"채피",
"타마샤",
"미스터 라잇",
"더 크루",
"스티브 잡스",
"익스트렉션",
"살인소설2: 다시 시작된 저주",
"리디큘러스 6",
"대니쉬 걸",
"아메리칸 울트라",
"젬 앤 더 홀로그램",
"더 메들러",
"바후발리: 더 비기닝",
"캅 카",
"비스트 오브 노 네이션",
"걸 킹 크리스티나",
"미니멀리즘 - 비우는 사람들의 이야기",
"그날의 진실",
"서프러제트",
"존 멀레이니: 더 컴백 키드",
"홈",
"Dream/Killer",
"Naomi and Ely's No Kiss List",
"الزين اللي فيك",
"마인드게이머스",
"ஓ காதல் கண்மணி",
"히 네버 다이: 뱀파이어의 전설",
"최악의 이웃과 사랑에 빠지는 방법",
"The Miracle",
"카스바",
"팬텀",
"Anthony Jeselnik: Thoughts and Prayers",
"피트니스 스캔들",
"LEGO Marvel Super Heroes: Avengers Reassembled!",
"딜 다다크네 도",
"의혹의 맹점",
"Cosmos Laundromat"
]
for i in list_2015:
    df= df_movie[df_movie['title']==i]
    print(df)
    df2 = df2.append(df)
    df2 = df2.reset_index(drop=True)

df2.to_csv('movies_top_2015.csv', sep=',', na_rep='NaN', index = None)
# Out:
#             id        title  \
# 165846  272693  퀸카가 아니어도 좋아
#
#                                                    genres  \
# 165846  [{'id': 10749, 'name': '로맨스'}, {'id': 35, 'nam...
#
#                                                  overview  \
# 165846  언제나 당당하고 거칠 것 없던 비앙카(메이 휘트먼 분)는 학교 홈커밍 행사를 한 달...
#
#                              poster_path release_date  runtime  popularity  \
# 165846  /2oX7X4zRHVuzuMtTSR3aOgvFukh.jpg   2015-02-20    101.0      23.282
#
#                                      production_countries
# 165846  [{'iso_3166_1': 'US', 'name': 'United States o...
#             id    title                         genres  \
# 206723  318256  핫 걸 원티드  [{'id': 99, 'name': '다큐멘터리'}]
#
#                                                  overview  \
# 206723  부모 곁을 떠나 자유를 찾으려는 소녀들. 생활비와 학비를 벌고 싶은 소녀들. 유명해...
#
#                              poster_path release_date  runtime  popularity  \
# 206723  /8efPmKDSgJV51IuB9AAy1yQQuzI.jpg   2015-05-29     84.0      37.951
#
# ...

# %%
df2 = pd.read_csv("frame.csv")
df2
# Out:
# Empty DataFrame
# Columns: [id, title, genres, overview, poster_path, release_date, runtime, popularity, production_countries]
# Index: []

# %%
list_2016=["더 홀 트루스",
"리브 바이 나이트",
"Lavender",
"녹터널 애니멀스",
"그레이터",
"화이트 걸",
"환생",
"인비저블 게스트",
"미스 슬로운",
"바스티유 데이",
"몬스터 콜",
"브레인 온 파이어",
"지랄발광 17세",
"스노든",
"나는 사랑과 시간과 죽음을 만났다",
"두 오버",
"워 독",
"미국 수정헌법 제13조",
"보살핌의 정석",
"ARQ",
"아만다 녹스",
"트리플 9",
"마더스 데이",
"고스트 워",
"포레스트: 죽음의 숲",
"내 인생 특별한 숲속 여행",
"로우",
"용쟁호투: 전설의 시작",
"로코",
"썸니아",
"프리 파이어",
"사일런트 레이크",
"판도라",
"허쉬",
"XOXO",
"캡틴 판타스틱",
"탈룰라",
"더 다크니스",
"목소리의 형태",
"Wild Oats",
"버려진 자들의 땅",
"인카네이트",
"배트맨: 더 킬링 조크",
"저주받은 집의 한 송이 꽃",
"헤드샷",
"마이 리틀 자이언트",
"와호장룡: 운명의 검",
"발레리나",
"케빈 하트: 왓 나우?",
"헤일, 시저!"]

for i in list_2016:
    df= df_movie[df_movie['title']==i]
    print(df)
    df2 = df2.append(df)
    df2 = df2.reset_index(drop=True)

df2.to_csv('movies_top_2016.csv', sep=',', na_rep='NaN', index = None)
# Out:
#             id    title                                             genres  \
# 218486  331583  더 홀 트루스  [{'id': 18, 'name': '드라마'}, {'id': 53, 'name':...
#
#                                                  overview  \
# 218486  마이크는 아버지 부운을 살해한 혐의로 경찰에 체포되었다. 변호사인 리차드는 부운 아...
#
#                              poster_path release_date  runtime  popularity  \
# 218486  /iL3Bx4YOqYdAMlx4czLyygA09MC.jpg   2016-03-25     93.0      10.466
#
#                                      production_countries
# 218486  [{'iso_3166_1': 'US', 'name': 'United States o...
#             id      title                                             genres  \
# 154610  259695  리브 바이 나이트  [{'id': 80, 'name': '범죄'}, {'id': 18, 'name': ...
#
#                                                  overview  \
# 154610  1920년대와 1930년대의 술이 마약처럼 거래되던 금주법 시대.  보스턴의 경찰 ...
#
#                              poster_path release_date  runtime  popularity  \
# ...

# %%
df2 = pd.read_csv("frame.csv")
df2
# Out:
# Empty DataFrame
# Columns: [id, title, genres, overview, poster_path, release_date, runtime, popularity, production_countries]
# Index: []

# %%
list_2017=["기억의 밤",
"리추얼: 숲속에 있다",
"7번째 내가 죽던 날",
"비뚤어진 집",
"Indian Horse",
"잇 컴스 앳 나잇",
"윈드 리버",
"사랑이란",
"월요일이 사라졌다",
"12번째 솔저",
"홀로 걷다",
"러브, 어게인",
"관음증자의 모텔",
"언레스트",
"1922",
"몸을 죽이는 자본의 밥상",
"이카로스",
"가질 수 있다면",
"디스커버리",
"배틀타임트랩: 초시공간여행",
"투 더 본",
"베를린 신드롬",
"뉴니스",
"샷 콜러",
"끝에서 시작되다",
"아이보이",
"피부",
"위험한 이웃",
"스페셜 시큐리티 : 라스트 미션",
"슬립리스: 크리미널 나이트",
"베로니카",
"누드 리플레이",
"클리니컬",
"루스에게 생긴 일",
"브라이트",
"고스트 스토리",
"Truth or Dare",
"카고",
"Desire",
"킬링 디어",
"레이디 버드",
"유니콘 스토어",
"매혹당한 사람들",
"옥자",
"배드 지니어스",
"샌드 캐슬",
"북 오브 헨리",
"햄스테드",
"굿타임",
"마셜"]

for i in list_2017:
    df= df_movie[df_movie['title']==i]
    print(df)
    df2 = df2.append(df)
    df2 = df2.reset_index(drop=True)

df2.to_csv('movies_top_2017.csv', sep=',', na_rep='NaN', index = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ed3089e1b8b> in <module>
#      51
#      52 for i in list_2017:
# ---> 53     df= df_movie[df_movie['title']==i]
#      54     print(df)
#      55     df2 = df2.append(df)
#
# NameError: name 'df_movie' is not defined

# %%
df= df_movie[df_movie['title']=="Desearás al hombre de tu hermana"]

# %%
df.to_csv('de.csv', sep=',', na_rep='NaN', index = None)
